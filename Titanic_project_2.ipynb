# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoMarte/Python_projects/blob/master/Titanic_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url='https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/train_titanic.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_titanic = pd.read_csv(url, error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic["Survived2"] = df_titanic["Survived"].map({0:"not_survived", 1:"survived"})

# %%
df_titanic["Pclass2"] = df_titanic["Pclass"].map({"C":1, "S":2,"Q":3})

# %%
sex_surv= pd.crosstab(df_titanic["Sex"], df_titanic["Survived2"])

# %%
sex_surv
# Out:
# Survived2  not_survived  survived
# Sex
# female               81       233
# male                468       109

# %%
sns.barplot(data= df_titanic,x= "Pclass", y= "Survived", hue="Sex")
plt.legend()
plt.show()

# %%
df_titanic["Sex2"] = df_titanic["Sex"].map({"male":0, "female":1})

# %%
df_titanic_short= df_titanic.groupby(["Age","Pclass","Survived","Sex"])

# %%
sns.barplot(data= df_titanic,x= "Pclass", y= "Survived")
plt.show()

# %%
df_titanic_short

# %%
df_titanic_short

# %%
sns.pairplot(df_titanic)
plt.show()

# %%
df_titanic_short.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic ["Age_int"]= np.int64(df_titanic["Age"])

# %%
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     Survived2  Pclass2  \
# 0      0         A/5 21171   7.2500   NaN        S  not_survived      NaN
# 1      0          PC 17599  71.2833   C85        C      survived      NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S      survived      NaN
# ...

# %%
sns.displot(data= df_titanic, x= "Age", hue= "Sex", multiple= "dodge")
plt.show()

# %%
sns.displot(data=df_titanic, x= "Sex", multiple= "dodge")
plt.show()

# %%
sns.catplot(data=df_titanic, x="Sex", y="Age", hue= "Survived2", dodge=True)
plt.show()

# %%
sns.violinplot(data=df_titanic, x="Sex", y="Age", hue= "Survived2", dodge=True)
plt.show()

# %%
sns.barplot(data=df_titanic, x="Sex", y="Age", hue= "Survived2", dodge=True)
plt.show()

# %%
sns.pairplot(data=df_titanic, hue="Survived", palette="coolwarm",corner=True, kind= "scatter")
plt.show()
