# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoMarte/Python_projects/blob/master/pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v1=np.linspace (0,5,11)
v2=v1**2

# %%
v1
v2
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
v1
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(v1,v2)
plt.show()

# %%
plt.plot(v1,v2, "r")
plt.show()

# %%
plt.plot(v1,v2, "ro")
plt.show()

# %%
plt.plot(v1,v2, "rx")
plt.show()

# %%
plt.plot(v1,v2, "rs-")
plt.show()

# %%
plt.hist(v1)
plt.show()

# %%
plt.hist(v2)
plt.show()
